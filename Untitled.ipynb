# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

trials = sio.loadmat('InOutputs.mat')
conds = sio.loadmat('InOutputs_condavg.mat')

# %%
print(trials['Outputs'][0].shape)
print(conds['Outputs'][0].shape)
# Out:
# (1,)
# (1,)

# %%
inputoutputs = sio.loadmat('InOutputs_condavg.mat')
Inputs   = inputoutputs['Inputs']
Outputs  = inputoutputs['Outputs']
Xnp      = np.expand_dims(Inputs, axis = 2)
ynp      = []
for cond_i in range(len(Outputs)):
    ynp.append(Outputs[cond_i][0])
ynp         = np.stack(ynp, axis = 0)

# %%
plt.plot(ynp[:, :, 0].T, label='1 2 3 4 5 6 7 8 9'.split(' '))
plt.legend(loc='upper left')
plt.show()

# %%
Inputs   = conds['Inputs']
Xnp      = np.expand_dims(Inputs, axis = 2)
Xnp.shape
# Out:
# (9, 44, 1)

# %%
tmp = []
for cond_i in range(len(conds['Outputs'])):
    tmp.append(conds['Outputs'][cond_i][0])

# %%
tmp[0].shape
# Out:
# (44, 2)

# %%
tmp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 tmp.shape
#
# AttributeError: 'list' object has no attribute 'shape'
